# %% [markdown]
# Importa Google Drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Ler Arquivo CSV com dados Climáticos e Casos de Dengue

# %%
data = pd.read_csv('/content/drive/My Drive/DS/Pos-Graducao-Uni7/Disc9-Programação/Trabalho do curso/Modelo-1/Limpeza dos dados/Sobral_Dados_Inmet.csv',sep=',')
data
# Out:
#             Data  Hora  Precipitacao  ...  Velocidade do Vento Media  Semana   Ano
# 0     01/01/2007     0           NaN  ...                   2.367027       1  2007
# 1     01/01/2007  1200           9.8  ...                        NaN       1  2007
# 2     02/01/2007     0           NaN  ...                   2.500000       1  2007
# 3     02/01/2007  1200           8.0  ...                        NaN       1  2007
# 4     03/01/2007     0           NaN  ...                   2.433333       1  2007
# ...          ...   ...           ...  ...                        ...     ...   ...
# 9481  29/12/2019  1200           0.0  ...                        NaN      53  2019
# 9482  30/12/2019     0           NaN  ...                   2.057760      53  2019
# 9483  30/12/2019  1200           0.0  ...                        NaN      53  2019
# 9484  31/12/2019     0           NaN  ...                   0.257220      53  2019
# ...

# %% [markdown]
# Ler localmente

# %%
# Verificar dados faltando no dataset
tot_nulos=data.isnull().sum()
tot_nulos
# Out:
# Data                            0
# Hora                            0
# Precipitacao                 4743
# TempMaxima                   4749
# TempMinima                   4720
# Insolacao                    4759
# Evaporacao Piche             4962
# Temp Comp Media              4753
# Umidade Relativa Media       4771
# Velocidade do Vento Media    4766
# Semana                          0
# Ano                             0
# dtype: int64

# %% [markdown]
# Ler Arquivo CSV com número de caso de Dengue

# %% [markdown]
# Substituir valores NAN por o valor da linha de baixo para a coluna Precipitação

# %%
data["Precipitacao"].fillna( method ='backfill', limit = 1, inplace = True) 
data["TempMinima"].fillna( method ='backfill', limit = 1, inplace = True) 
data["TempMaxima"].fillna( method ='backfill', limit = 1, inplace = True) 
data["Insolacao"].fillna( method ='backfill', limit = 1, inplace = True) 
data["Evaporacao Piche"].fillna( method ='backfill', limit = 1, inplace = True) 
data["Temp Comp Media"].fillna( method ='backfill', limit = 1, inplace = True) 
data["Umidade Relativa Media"].fillna( method ='backfill', limit = 1, inplace = True) 
data["Velocidade do Vento Media"].fillna( method ='backfill', limit = 1, inplace = True)

# %% [markdown]
# Substituir valores NAN por o valor da linha de baixo para a coluna TempMinima

# %%
data
# Out:
#             Data  Hora  Precipitacao  ...  Velocidade do Vento Media  Semana   Ano
# 0     01/01/2007     0           9.8  ...                   2.367027       1  2007
# 1     01/01/2007  1200           9.8  ...                   2.500000       1  2007
# 2     02/01/2007     0           8.0  ...                   2.500000       1  2007
# 3     02/01/2007  1200           8.0  ...                   2.433333       1  2007
# 4     03/01/2007     0           0.7  ...                   2.433333       1  2007
# ...          ...   ...           ...  ...                        ...     ...   ...
# 9481  29/12/2019  1200           0.0  ...                   2.057760      53  2019
# 9482  30/12/2019     0           0.0  ...                   2.057760      53  2019
# 9483  30/12/2019  1200           0.0  ...                   0.257220      53  2019
# 9484  31/12/2019     0          31.4  ...                   0.257220      53  2019
# ...

# %% [markdown]
# Exibe o Dataframe somente com as linhas pares

# %%
Indices=[x for x in data.index if x%2==1]
data.drop(Indices, inplace=True)

# %% [markdown]
# Reindexa os Indices para que a concatenação posterior seja possível

# %%
data.reset_index(inplace = True, drop = True)

# %%
data
# Out:
#             Data  Hora  Precipitacao  ...  Velocidade do Vento Media  Semana   Ano
# 0     01/01/2007     0           9.8  ...                   2.367027       1  2007
# 1     02/01/2007     0           8.0  ...                   2.500000       1  2007
# 2     03/01/2007     0           0.7  ...                   2.433333       1  2007
# 3     04/01/2007     0           1.9  ...                   2.000000       1  2007
# 4     05/01/2007     0           0.0  ...                   2.500000       1  2007
# ...          ...   ...           ...  ...                        ...     ...   ...
# 4738  27/12/2019     0           0.0  ...                   2.057760      52  2019
# 4739  28/12/2019     0           0.0  ...                   2.057760      52  2019
# 4740  29/12/2019     0           0.0  ...                   2.572200      53  2019
# 4741  30/12/2019     0           0.0  ...                   2.057760      53  2019
# ...

# %%
# Plotagem dos dados

plt.xlabel('Precipitacao x Infectados')
#plt.ylabel('Precipitação')
plt.plot(data2['N.Infectados'])
plt.plot(data['Precipitacao'])
plt.gca().legend(('Infectados','Precipitacao'))
plt.show()

# %% [markdown]
# Agrupando dados Semanais

# %%
data = data.groupby(by=['Ano','Semana'])['Precipitacao','TempMaxima','TempMinima','Insolacao','Evaporacao Piche','Temp Comp Media',	'Umidade Relativa Media',	'Velocidade do Vento Media'].sum()
data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              Precipitacao  ...  Velocidade do Vento Media
# Ano  Semana                ...
# 2007 1               20.4  ...                  14.800360
#      2                5.3  ...                  11.266668
#      3                0.5  ...                  17.366667
#      4                0.0  ...                  16.014440
#      5                2.7  ...                  19.366667
# ...                   ...  ...                        ...
# 2019 49               0.0  ...                  13.118220
#      50               0.0  ...                  14.661540
#      51               0.0  ...                  13.889880
#      52               0.0  ...                  13.118220
#      53              31.4  ...                   4.887180
#
# ...

# %%
data
# Out:
#              Precipitacao  ...  Velocidade do Vento Media
# Ano  Semana                ...
# 2007 1               20.4  ...                  14.800360
#      2                5.3  ...                  11.266668
#      3                0.5  ...                  17.366667
#      4                0.0  ...                  16.014440
#      5                2.7  ...                  19.366667
# ...                   ...  ...                        ...
# 2019 49               0.0  ...                  13.118220
#      50               0.0  ...                  14.661540
#      51               0.0  ...                  13.889880
#      52               0.0  ...                  13.118220
#      53              31.4  ...                   4.887180
#
# [689 rows x 8 columns]

# %%
#Lê dados Infectados e 
file='/content/drive/My Drive/DS/Pos-Graducao-Uni7/Disc9-Programação/Trabalho do curso/Modelo-1/Limpeza dos dados/Sobral_Dados_Infectados.csv'
data2 = pd.read_csv(file,sep=',')
data2["N.Infectados"].fillna( method = 'backfill', limit = 1, inplace = True)
# Out:
#             data  N.Infectados  Semana
# 0     01/01/2007             4       1
# 1     02/01/2007             0       1
# 2     03/01/2007             0       1
# 3     04/01/2007             0       1
# 4     05/01/2007             0       1
# ...          ...           ...     ...
# 4743  27/12/2019             0      52
# 4744  28/12/2019             0      52
# 4745  29/12/2019             0      53
# 4746  30/12/2019             0      53
# 4747  31/12/2019             0      53
#
# [4748 rows x 3 columns]

# %%
data2.drop(data2.tail(5).index,inplace=True) # drop last n rows
data2
# Out:
#             data  N.Infectados  Semana
# 0     01/01/2007             4       1
# 1     02/01/2007             0       1
# 2     03/01/2007             0       1
# 3     04/01/2007             0       1
# 4     05/01/2007             0       1
# ...          ...           ...     ...
# 4738  22/12/2019             0      52
# 4739  23/12/2019             0      52
# 4740  24/12/2019             0      52
# 4741  25/12/2019             0      52
# 4742  26/12/2019             0      52
#
# [4743 rows x 3 columns]

# %%
data.to_csv('/content/drive/My Drive/DS/Pos-Graducao-Uni7/Disc9-Programação/Trabalho do curso/Modelo-1/Limpeza dos dados/Sobral_Dados_Inmet2.csv')
data2.to_csv('/content/drive/My Drive/DS/Pos-Graducao-Uni7/Disc9-Programação/Trabalho do curso/Modelo-1/Limpeza dos dados/Sobral_Dados_Infectados2.csv')
