# %% [markdown]
# # Predição de Dengue - Modelos de Classificaao KNN e SVM

# %% [markdown]
# ## Autor - Francisco Flávio Cardoso Gomes
# ## Fonte de dados
# ###  - Dados Metereológicos - Inmet - Instituto Nacional de Metereologia
# ###  - Dados de Infectados por dengue - SinanWeb - Sistema de Notificação de Agravos e Notificação

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import  pyplot as plt

from warnings import filterwarnings
filterwarnings('ignore')
import time as time

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ### Ler Arquivos CSV

# %%
file='./Dados/Fortaleza/Fortaleza_Inmet_Diario_Corrigido.csv'
data = pd.read_csv(file,sep=',')
data = data.rename(columns={'Evaporacao Piche': 'Evaporacao', 'Temp Comp Media': 'TempMedia','Umidade Relativa Media':'Umidade','Velocidade do Vento Media':'VelVento'})
data
# Out:
#       Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 0       82397  01/01/2007     0           0.0   30.600000        27.4
# 1       82397  02/01/2007     0           0.0   32.000000        27.1
# 2       82397  03/01/2007     0           0.5   29.500000        25.9
# 3       82397  04/01/2007     0           7.9   31.300000        25.9
# 4       82397  05/01/2007     0           2.7   28.700000        24.0
# ...       ...         ...   ...           ...         ...         ...
# 4921    82397  22/06/2019  1200           0.0   31.362319        23.3
# 4922    82397  23/06/2019  1200           0.0   31.362319        23.3
# 4923    82397  24/06/2019     0           0.0   30.500000        23.7
# 4924    82397  25/06/2019     0           0.0   30.600000        23.3
# 4925    82397  26/06/2019     0           0.0   31.000000        23.3
#
#       Insolacao  Evaporacao  TempMedia   Umidade  VelVento  Semana   Ano
# 0      8.300000    7.300000  28.000000  74.00000  3.971840       1  2007
# 1     11.300000    6.900000  28.820000  69.50000  3.966667       1  2007
# 2      1.300000    8.200000  27.240000  81.75000  2.433333       1  2007
# 3     11.200000    3.100000  27.800000  71.50000  3.166667       1  2007
# 4      3.000000    5.900000  26.520000  83.75000  3.766667       1  2007
# ...         ...         ...        ...       ...       ...     ...   ...
# 4921   7.713613    4.242638  27.176183  77.73468  2.808384      25  2019
# 4922   7.713613    4.242638  27.176183  77.73468  2.808384      25  2019
# 4923   8.900000    4.242638  26.480000  77.00000  1.286100      26  2019
# 4924   8.800000    4.242638  26.540000  80.00000  2.057760      26  2019
# 4925   9.300000    4.242638  26.840000  77.00000  2.829420      26  2019
#
# [4926 rows x 13 columns]

# %% [markdown]
# ### Incluindo colunas Ano e Semana para Agrupamento

# %%
file2='./Dados/Fortaleza/Fortaleza_Infectados_Diarios.csv'
data2 = pd.read_csv(file2,sep=',')
data2 = data2.rename(columns={'Data_Notificacao':'Data','Infectados_Dengue':'Infectados'})
data2
# Out:
#             Data  Infectados  Semana   Ano
# 0     01/01/2007           6       1  2007
# 1     02/01/2007          10       1  2007
# 2     03/01/2007          26       1  2007
# 3     04/01/2007          20       1  2007
# 4     05/01/2007          22       1  2007
# ...          ...         ...     ...   ...
# 4921  22/06/2020           4      26  2020
# 4922  23/06/2020           4      26  2020
# 4923  24/06/2020           0      26  2020
# 4924  25/06/2020           0      26  2020
# 4925  26/06/2020           0      26  2020
#
# [4926 rows x 4 columns]

# %% [markdown]
# ### Verificar dados faltando no dataset Inmet

# %%
tot_nulos=data.isnull().sum()
tot_nulos
# Out:
# Estacao         0
# Data            0
# Hora            0
# Precipitacao    0
# TempMaxima      0
# TempMinima      0
# Insolacao       0
# Evaporacao      0
# TempMedia       0
# Umidade         0
# VelVento        0
# Semana          0
# Ano             0
# dtype: int64

# %%
data
# Out:
#       Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 0       82397  01/01/2007     0           0.0   30.600000        27.4
# 1       82397  02/01/2007     0           0.0   32.000000        27.1
# 2       82397  03/01/2007     0           0.5   29.500000        25.9
# 3       82397  04/01/2007     0           7.9   31.300000        25.9
# 4       82397  05/01/2007     0           2.7   28.700000        24.0
# ...       ...         ...   ...           ...         ...         ...
# 4921    82397  22/06/2019  1200           0.0   31.362319        23.3
# 4922    82397  23/06/2019  1200           0.0   31.362319        23.3
# 4923    82397  24/06/2019     0           0.0   30.500000        23.7
# 4924    82397  25/06/2019     0           0.0   30.600000        23.3
# 4925    82397  26/06/2019     0           0.0   31.000000        23.3
#
#       Insolacao  Evaporacao  TempMedia   Umidade  VelVento  Semana   Ano
# 0      8.300000    7.300000  28.000000  74.00000  3.971840       1  2007
# 1     11.300000    6.900000  28.820000  69.50000  3.966667       1  2007
# 2      1.300000    8.200000  27.240000  81.75000  2.433333       1  2007
# 3     11.200000    3.100000  27.800000  71.50000  3.166667       1  2007
# 4      3.000000    5.900000  26.520000  83.75000  3.766667       1  2007
# ...         ...         ...        ...       ...       ...     ...   ...
# 4921   7.713613    4.242638  27.176183  77.73468  2.808384      25  2019
# 4922   7.713613    4.242638  27.176183  77.73468  2.808384      25  2019
# 4923   8.900000    4.242638  26.480000  77.00000  1.286100      26  2019
# 4924   8.800000    4.242638  26.540000  80.00000  2.057760      26  2019
# 4925   9.300000    4.242638  26.840000  77.00000  2.829420      26  2019
#
# [4926 rows x 13 columns]

# %% [markdown]
# ### Agrupando dados Metereológicos para Semanais

# %%
dataSemana = data.groupby(by=['Ano','Semana'], as_index=False)['Precipitacao','TempMaxima','TempMinima','Insolacao','Evaporacao','TempMedia',	'Umidade',	'VelVento'].sum()

# %%
dataSemana
# Out:
#       Ano  Semana  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    2007       1          17.9       183.6       155.2       45.5
# 1    2007       2          18.2       220.9       177.7       58.6
# 2    2007       3           1.2       226.1       184.9       59.3
# 3    2007       4           0.0       225.2       183.9       62.2
# 4    2007       5           9.7       223.8       184.6       43.4
# ..    ...     ...           ...         ...         ...        ...
# 704  2020      20         103.4       208.4       170.4       29.3
# 705  2020      21         180.7       219.5       169.6       36.5
# 706  2020      22          41.0       221.5       168.6       57.0
# 707  2020      23          14.2       219.9       169.3       50.2
# 708  2020      24           4.2        62.2        47.0       15.5
#
#      Evaporacao   TempMedia  Umidade   VelVento
# 0     35.000000  166.320000   454.25  21.605174
# 1     40.100000  195.440000   541.25  23.466666
# 2     39.200000  199.820000   520.75  24.966668
# 3     45.600000  199.860000   511.50  23.214440
# 4     38.600000  198.180000   543.25  20.033333
# ..          ...         ...      ...        ...
# 704   29.698468  191.808550   614.00  16.656193
# 705   29.698468  190.233283   600.00  19.658690
# 706   29.698468  190.233283   583.00  19.658690
# 707   29.698468  190.233283   593.00  19.658690
# 708    8.485277   54.352367   172.00   5.616768
#
# [709 rows x 10 columns]

# %% [markdown]
# ### Examina o gráfico dos atributos

# %%
plt.figure(figsize=(20,10))
data.Precipitacao.plot(label="Precipitação")
data.TempMedia.plot( label="Temperatura Média")
data.Umidade.plot( label="Umidade Relativa do ar")
data.Evaporacao.plot( label="Evaporação Piche")
data.VelVento.plot( label="Velocidade do Vento")
plt.title("Variáveis Independentes")
plt.legend()
plt.xlabel('Dados Semanais')
plt.ylabel('Valores')

plt.show()

# %% [markdown]
# ### Verifica Nulos da variável dependente - N. de infectados.

# %%
tot_nulos=data2.isnull().sum()
tot_nulos
# Out:
# Data          0
# Infectados    0
# Semana        0
# Ano           0
# dtype: int64

# %%
data2
# Out:
#             Data  Infectados  Semana   Ano
# 0     01/01/2007           6       1  2007
# 1     02/01/2007          10       1  2007
# 2     03/01/2007          26       1  2007
# 3     04/01/2007          20       1  2007
# 4     05/01/2007          22       1  2007
# ...          ...         ...     ...   ...
# 4921  22/06/2020           4      26  2020
# 4922  23/06/2020           4      26  2020
# 4923  24/06/2020           0      26  2020
# 4924  25/06/2020           0      26  2020
# 4925  26/06/2020           0      26  2020
#
# [4926 rows x 4 columns]

# %% [markdown]
# ### Agrupar  por semana e plota o gráfico da variável dependente

# %%
data2Semana = data2.groupby(by=['Ano','Semana'], as_index=False).sum()
for col_name in data2Semana:
    print(col_name)
data2Semana=data2Semana.iloc[:580]
# Out:
# Ano
# Semana
# Infectados

# %%
data2Semana.describe()
# Out:
#                Ano      Semana   Infectados
# count   580.000000  580.000000   580.000000
# mean   2011.974138   26.870690   454.720690
# std       3.152599   15.243295   842.358399
# min    2007.000000    1.000000     2.000000
# 25%    2009.000000   14.000000    70.500000
# 50%    2012.000000   27.000000   174.000000
# 75%    2015.000000   40.000000   427.500000
# max    2017.000000   53.000000  6233.000000

# %%
# Analisar dados de "Infectados" ao longo do tempo
plt.figure(figsize=(20,10))
plt.xlabel('Dados Semanais')
plt.ylabel('Infectados')
plt.plot(data2Semana['Infectados'])
plt.show()

# %% [markdown]
# ### Separando dados para treino e teste

# %%
dataSemana=dataSemana.iloc[0:580]
dataSemana.loc[:,'Ano']
# Out:
# 0      2007
# 1      2007
# 2      2007
# 3      2007
# 4      2007
#        ...
# 575    2017
# 576    2017
# 577    2017
# 578    2017
# 579    2017
# Name: Ano, Length: 580, dtype: int64

# %%
X_train=dataSemana.iloc[:380]
X_test=dataSemana.iloc[381:]
y_train = data2Semana.iloc[:380]
submission = data2Semana.iloc[381:]

X_train,X_test
# Out:
# (      Ano  Semana  Precipitacao  TempMaxima  TempMinima  Insolacao  \
#  0    2007       1          17.9       183.6       155.2       45.5
#  1    2007       2          18.2       220.9       177.7       58.6
#  2    2007       3           1.2       226.1       184.9       59.3
#  3    2007       4           0.0       225.2       183.9       62.2
#  4    2007       5           9.7       223.8       184.6       43.4
#  ..    ...     ...           ...         ...         ...        ...
#  375  2014       5          28.2       222.4       167.8       57.1
#  376  2014       6          74.4       216.8       161.6       48.6
#  377  2014       7          26.9       216.9       168.4       47.2
#  378  2014       8          42.9       212.8       161.4       32.8
#  379  2014       9           0.0       222.3       165.9       66.7
#
#       Evaporacao  TempMedia  Umidade   VelVento
#  0          35.0     166.32   454.25  21.605174
#  1          40.1     195.44   541.25  23.466666
#  2          39.2     199.82   520.75  24.966668
#  3          45.6     199.86   511.50  23.214440
#  4          38.6     198.18   543.25  20.033333
#  ..          ...        ...      ...        ...
#  375        33.8     192.62   541.50  19.300000
#  376        27.4     187.86   557.75  14.966668
#  377        23.9     191.02   572.00  19.166667
#  378        18.4     186.20   579.00  16.700001
#  379        28.4     191.82   538.50  16.433334
#
#  [380 rows x 10 columns],
#        Ano  Semana  Precipitacao  TempMaxima  TempMinima  Insolacao  \
#  381  2014      11          54.4       216.0       165.6       37.3
#  382  2014      12          88.9       216.7       164.3       30.1
#  383  2014      13           8.5       221.9       168.1       54.9
#  384  2014      14         179.4       209.5       162.7       23.4
#  385  2014      15          87.0       217.7       162.8       44.7
#  ..    ...     ...           ...         ...         ...        ...
#  575  2017      46           6.5       220.7       173.0       67.9
#  576  2017      47           0.2       221.8       175.2       62.7
#  577  2017      48           3.8       221.6       177.2       71.1
#  578  2017      49           0.0       228.9       179.3       75.3
#  579  2017      50           1.4       226.2       179.3       74.9
#
#       Evaporacao  TempMedia  Umidade   VelVento
#  381        20.8     189.48   570.25  13.433334
#  382        17.5     189.46   586.50  17.633334
#  383        24.2     193.22   552.75  14.433333
#  384        12.3     185.02   612.25   9.066666
#  385        16.4     186.28   600.25   9.700000
#  ..          ...        ...      ...        ...
#  575        36.5     193.06   504.50  21.900000
#  576        26.3     194.04   524.50  19.533333
#  577        38.4     194.40   521.50  21.100000
#  578        36.4     199.14   512.00  22.066668
#  579        40.5     198.60   503.50  20.466667
#
#  [199 rows x 10 columns])

# %%
## Dados de Treino
plt.figure(figsize=(30,10))
X_train.Precipitacao.plot(label="Precipitação")
X_train.TempMedia.plot( label="Temperatura Média")
X_train.Umidade.plot( label="Umidade Relativa do ar")
X_train.Evaporacao.plot( label="Evaporação Piche")
X_train.VelVento.plot( label="Velocidade do Vento")
plt.title("Dados de Treino")
plt.legend()
plt.xlabel('Dados Semanais')
plt.ylabel('Valores')

plt.show()

# %%
## Dados de Teste
plt.figure(figsize=(30,10))
X_test.Precipitacao.plot(label="Precipitação")
X_test.TempMedia.plot( label="Temperatura Média")
X_test.Umidade.plot( label="Umidade Relativa do ar")
X_test.Evaporacao.plot( label="Evaporação Piche")
X_test.VelVento.plot( label="Velocidade do Vento")
plt.title("Dados de Teste")
plt.legend()
plt.xlabel('Dados Semanais')
plt.ylabel('Valores')

plt.show()

# %% [markdown]
# ### Normalizador estatístico, onde o resultado da normalização garante média zero e variância/desvio parão unitária.

# %%
normalizador = StandardScaler()

X_train.iloc[:,2:] = normalizador.fit_transform(X_train.iloc[:,2:])
X_test.iloc[:,2:] = normalizador.transform(X_test.iloc[:,2:])
X_train,X_test,
# Out:
# (      Ano  Semana  Precipitacao  TempMaxima  TempMinima  Insolacao  \
#  0    2007       1     -0.243068   -1.478775   -0.547111  -0.561694
#  1    2007       2     -0.236339    0.246909    0.784234   0.276746
#  2    2007       3     -0.617682    0.487487    1.210264   0.321548
#  3    2007       4     -0.644601    0.445848    1.151093   0.507157
#  4    2007       5     -0.427010    0.381077    1.192513  -0.696101
#  ..    ...     ...           ...         ...         ...        ...
#  375  2014       5     -0.012019    0.316306    0.198442   0.180741
#  376  2014       6      1.024339    0.057222   -0.168417  -0.363285
#  377  2014       7     -0.041180    0.061849    0.233944  -0.452889
#  378  2014       8      0.317731   -0.127837   -0.180252  -1.374533
#  379  2014       9     -0.644601    0.311680    0.086017   0.795171
#
#       Evaporacao  TempMedia   Umidade  VelVento
#  0      0.422074  -1.092734 -1.197580  0.262751
#  1      0.853656   0.473208  0.159881  0.586435
#  2      0.777495   0.708745 -0.159981  0.847262
#  3      1.319088   0.710896 -0.304309  0.542577
#  4      0.726721   0.620553  0.191087 -0.010567
#  ..          ...        ...       ...       ...
#  375    0.320526   0.321562  0.163781 -0.138082
#  376   -0.221068   0.065590  0.417330 -0.891581
#  377   -0.517251   0.235521  0.639673 -0.161267
#  378   -0.982683  -0.023677  0.748894 -0.590181
#  379   -0.136444   0.278541  0.116972 -0.636551
#
#  [380 rows x 10 columns],
#        Ano  Semana  Precipitacao  TempMaxima  TempMinima  Insolacao  \
#  381  2014      11      0.575699    0.020210    0.068266  -1.086520
#  382  2014      12      1.349602    0.052596   -0.008656  -1.547342
#  383  2014      13     -0.453929    0.293174    0.216193   0.039935
#  384  2014      14      3.379696   -0.280512   -0.103330  -1.976162
#  385  2014      15      1.306982    0.098861   -0.097412  -0.612897
#  ..    ...     ...           ...         ...         ...        ...
#  575  2017      46     -0.498793    0.237656    0.506130   0.871974
#  576  2017      47     -0.640114    0.288547    0.636306   0.539159
#  577  2017      48     -0.559359    0.279294    0.754648   1.076784
#  578  2017      49     -0.644601    0.617029    0.878907   1.345597
#  579  2017      50     -0.613196    0.492113    0.878907   1.319996
#
#       Evaporacao  TempMedia   Umidade  VelVento
#  381   -0.779585   0.152707  0.612368 -1.158203
#  382   -1.058844   0.151631  0.865916 -0.427889
#  383   -0.491864   0.353827  0.339315 -0.984319
#  384   -1.498889  -0.087132  1.267694 -1.917498
#  385   -1.151931  -0.019375  1.080458 -1.807371
#  ..          ...        ...       ...       ...
#  575    0.549010   0.345223 -0.413530  0.314017
#  576   -0.314154   0.397923 -0.101470 -0.097510
#  577    0.709796   0.417282 -0.148279  0.174909
#  578    0.540548   0.672178 -0.296507  0.342998
#  579    0.887506   0.643139 -0.429133  0.064783
#
#  [199 rows x 10 columns])

# %%
## Dados de Teste
plt.figure(figsize=(30,10))
X_train.Precipitacao.plot(label="Precipitação")
X_train.TempMedia.plot( label="Temperatura Média")
X_train.Umidade.plot( label="Umidade Relativa do ar")
X_train.Evaporacao.plot( label="Evaporação Piche")
X_train.VelVento.plot( label="Velocidade do Vento")
plt.title("Dados de Treino")
plt.legend()
plt.xlabel('Dados Semanais')
plt.ylabel('Valores')

plt.show()

# %%
## Dados de Teste
plt.figure(figsize=(30,10))
X_test.Precipitacao.plot(label="Precipitação")
X_test.TempMedia.plot( label="Temperatura Média")
X_test.Umidade.plot( label="Umidade Relativa do ar")
X_test.Evaporacao.plot( label="Evaporação Piche")
X_test.VelVento.plot( label="Velocidade do Vento")
plt.title("Dados de Teste")
plt.legend()
plt.xlabel('Dados Semanais')
plt.ylabel('Valores')

plt.show()

# %% [markdown]
# Nossa variável de destino, "Infectados" é um número inteiro não negativo, o que significa que estamos procurando fazer algumas previsões de contagem. As técnicas de regressão padrão para esse tipo de previsão incluem:
# Regressão de Poisson
# Regressão binomial negativa.
#
# Qual técnica terá melhor desempenho depende de muitas coisas, mas a escolha entre a regressão de Poisson e a regressão binomial negativa é bastante direta.
#
# A regressão de Poisson se ajusta de acordo com a suposição de que a média e a variância da distribuição da população são iguais. Quando não são, especificamente quando a variação é muito maior que a média, a abordagem binomial negativa é melhor.
#
# A regressão binomial negativa simplesmente levanta a suposição de que a média e variância da população são iguais, permitindo uma classe maior de modelos possíveis. De fato, dessa perspectiva, a distribuição de Poisson é apenas um caso especial da distribuição binomial negativa.

# %%
y_train.describe()
# Out:
#                Ano      Semana   Infectados
# count   380.000000  380.000000   380.000000
# mean   2010.094737   26.478947   519.934211
# std       2.070390   15.506134   981.399966
# min    2007.000000    1.000000     2.000000
# 25%    2008.000000   13.000000    82.750000
# 50%    2010.000000   26.000000   183.000000
# 75%    2012.000000   40.000000   443.250000
# max    2014.000000   53.000000  6233.000000

# %%
# Dados de "Infectados" de treino
plt.figure(figsize=(20,10))
plt.xlabel('Dados Semanais')
plt.ylabel('Infectados')
plt.plot(data2Semana['Infectados'])
plt.show()

# %%
# Dados de "Infectados" de teste
plt.figure(figsize=(20,10))
plt.xlabel('Dados Semanais')
plt.ylabel('Infectados')
plt.plot(submission['Infectados'])
plt.show()

# %%
print('Media e Variancia dos Infectados')
print('mean: ', y_train.mean()[2])
print('std :', y_train.std()[2])
print('var :', y_train.var()[2])
# Out:
# Media e Variancia dos Infectados
# mean:  519.9342105263158
# std : 981.3999657417709
# var : 963145.8927579491

# %% [markdown]
# Variancia maior que media sugere que a variável "Infectados" pode ser descrita por uma distribuição binomial negativa; portanto, usaremos uma regressão binomial negativa abaixo.
#
# Vamos analisar as Correlações

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(X_train.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
ax.set_title('Correlações')
plt.show()

# %% [markdown]
# ### Verifica-se que TempMaxima e TemMinima estão fortemente relacionada com TempMedia, sugerindo que podemos excluir estes 2  atributos.

# %%
delete = ['TempMinima','TempMaxima']
for z in delete:
    del X_train[z]
    del X_test[z]

# %%
X_train['Infectados'] = y_train['Infectados']

f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(X_train.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
ax.set_title('Correlações')
plt.show()

# %% [markdown]
# ### Vamos verificar a correlação dos atributos com a variável dependente

# %%
correlations = X_train.corr()
(correlations['Infectados'].drop('Infectados').sort_values(ascending=False).plot.barh())
plt.title('Correlações')
# Out:
# Text(0.5, 1.0, 'Correlações')

# %% [markdown]
# ### Verificamos que Vel. Vento, Umidade e Evaporação estão mais fortemente correlacionadas com Infectados do que a precipitação. Isto foi uma surpresa

# %% [markdown]
# ### Vamos plotar o número de infectados para cada ano

# %%
#Numero de Casos por semana
for i in set(y_train['Ano']):
    df = y_train[y_train['Ano'] == i]
    df.set_index('Semana', drop = True, inplace = True)
    plt.plot(df['Infectados'], alpha = .3)
    
y_train.groupby('Semana')['Infectados'].mean().plot(c = 'k', figsize = (10,4))
plt.legend(set(y_train['Ano']), loc='center left', bbox_to_anchor=(1, .5))

plt.title('Número de casos por ano  ')
plt.xlabel('Semana do ano')
plt.ylabel('Total de Infectados')
# Out:
# Text(0, 0.5, 'Total de Infectados')

# %% [markdown]
# ###  Verificas uma incidência maior de dengue no final do primeiro semestre, que coincide com o final do período chuvoso no Ceará

# %% [markdown]
# ## Construindo modelos de Machine Learning
# ### Agora que temos uma compreensão mais clara do nosso conjunto de dados, continuaremos a construir nossos modelos de ML.

# %%
#features=['Infectados','Precipitacao','Insolacao','Evaporacao','TempMedia','Umidade','VelVento'] 
features=['Infectados','Precipitacao','Insolacao','Evaporacao','Umidade','VelVento'] 

X_train=X_train.join(X_train.groupby(['Semana'])['Infectados'].mean(), on=['Semana'], rsuffix='_avg')
X_test=X_test.join(X_train.groupby(['Semana'])['Infectados'].mean(), on=['Semana'], rsuffix='_avg')

#TRAIN
X= X_train[features]
Y = X_train['Infectados']

#TEST
Xt= X_test[features]
X.fillna(method='bfill', inplace=True)
Xt.fillna(method='bfill', inplace=True)

# %% [markdown]
# ## Criando os modelos e treinando

# %% [markdown]
# ### SVM - (Support Vetor Machine / SRV - Support vetor Regression)

# %%
svr = GridSearchCV(SVR(kernel='rbf', gamma=0.1), cv=5,
                   param_grid={"C": [1e0, 1e1, 1e2, 1e3],
                               "gamma": np.logspace(-2, 2, 5)})
t0 = time.time()
svr.fit(X,Y)

svr_fit = time.time() - t0
print("Complexidade SVR e largura de banda selecionadas e modelo ajustado em %.3f s"
      % svr_fit)
model=svr.best_estimator_
print(model)
# Out:
# Complexidade SVR e largura de banda selecionadas e modelo ajustado em 3.693 s
# SVR(C=1000.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.01,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# ###   KNN (k-nearest neighbors )

# %%
knn = KNeighborsClassifier(n_neighbors = 30)
knn.fit(X,Y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=30, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Separa dados de TREINO (70%)  e teste (30%) Para VALIDAÇÃO

# %%
train_subtrain = X_train.sample(frac=0.7)
train_subtest = X_train.loc[~X_train.index.isin(train_subtrain.index)]

train_subtrain.fillna(method='bfill', inplace=True)
train_subtest.fillna(method='bfill', inplace=True)

#X_train.describe()
train_subtest.describe()
# Out:
#                Ano      Semana  Precipitacao   Insolacao  Evaporacao  \
# count   114.000000  114.000000    114.000000  114.000000  114.000000
# mean   2009.885965   25.052632     -0.150723    0.028706    0.018537
# std       1.990058   15.412811      0.733010    0.976363    1.002671
# min    2007.000000    1.000000     -0.644601   -2.744199   -2.125106
# 25%    2008.000000   12.000000     -0.635067   -0.560094   -0.591297
# 50%    2010.000000   25.000000     -0.499914    0.225543   -0.026562
# 75%    2011.000000   38.000000      0.107992    0.799971    0.529970
# max    2014.000000   53.000000      2.722439    1.351998    3.747795
#
#         TempMedia     Umidade    VelVento   Infectados  Infectados_avg
# count  114.000000  114.000000  114.000000   114.000000      114.000000
# mean    -0.029281   -0.055516    0.037240   464.131579      506.283835
# std      1.101706    1.073913    0.939611   830.881007      553.603490
# min     -8.530960   -7.200834   -2.949212     4.000000       68.375000
# 25%     -0.048952   -0.405728   -0.629305    85.500000      151.142857
# 50%      0.139800    0.015553    0.082171   197.000000      254.500000
# 75%      0.303278    0.495345    0.840016   402.500000      708.714286
# max      0.863619    1.509540    1.751522  5195.000000     1970.714286

# %% [markdown]
# ### Cria Predições

# %%
preds= model.predict(train_subtest[features]).astype(int)
newPreds = model.predict(X_test[features]).astype(int)
#SVM
#add to the dataframes
train_subtest['fitted'] = preds
X_test['fitted'] = newPreds

# KNN
preds2 = knn.predict(train_subtest[features]).astype(int)
newPreds2 = knn.predict(X_test[features]).astype(int)
train_subtest['fitted2'] = preds2
X_test['fitted2'] = newPreds2
#train_subtest.index = train_subtest['week_start_date']

# %%
X_test
# Out:
#       Ano  Semana  Precipitacao  Insolacao  Evaporacao  TempMedia   Umidade  \
# 381  2014      11      0.575699  -1.086520   -0.779585   0.152707  0.612368
# 382  2014      12      1.349602  -1.547342   -1.058844   0.151631  0.865916
# 383  2014      13     -0.453929   0.039935   -0.491864   0.353827  0.339315
# 384  2014      14      3.379696  -1.976162   -1.498889  -0.087132  1.267694
# 385  2014      15      1.306982  -0.612897   -1.151931  -0.019375  1.080458
# ..    ...     ...           ...        ...         ...        ...       ...
# 575  2017      46     -0.498793   0.871974    0.549010   0.345223 -0.413530
# 576  2017      47     -0.640114   0.539159   -0.314154   0.397923 -0.101470
# 577  2017      48     -0.559359   1.076784    0.709796   0.417282 -0.148279
# 578  2017      49     -0.644601   1.345597    0.540548   0.672178 -0.296507
# 579  2017      50     -0.613196   1.319996    0.887506   0.643139 -0.429133
#
#      VelVento   Infectados  fitted  fitted2
# 381 -1.158203   609.142857     599      627
# 382 -0.427889   717.571429     717      627
# 383 -0.984319   882.142857     893      888
# 384 -1.917498  1082.428571     997      888
# 385 -1.807371  1437.000000    1030      888
# ..        ...          ...     ...      ...
# 575  0.314017   103.000000      91       97
# 576 -0.097510   124.714286     133      115
# 577  0.174909   131.000000     144      117
# 578  0.342998   156.142857     156      138
# 579  0.064783   180.714286     192      189
#
# [199 rows x 11 columns]

# %% [markdown]
# ### Plotagem das predições com parte de dados de VALIDAÇÃO

# %%
plt.figure(figsize=(35,10))
train_subtest.Infectados.plot(label="Reais")
train_subtest.fitted.plot( label="Predição com SVM")
train_subtest.fitted2.plot( label="Predicões com KNN")

plt.title("Dengue Casos Preditos vs. Casos Reais")
plt.legend()
plt.xlabel('N. de Semanas')
plt.ylabel('Total de Infectados')
# Out:
# Text(0, 0.5, 'Total de Infectados')

# %% [markdown]
# ## Calcula as métricas  - Cross validation com o score R2

# %% [markdown]
# ### Scores para SVR

# %%
scores = cross_val_score(svr, X,Y, cv=5, scoring = "r2")
print("Scores usando SVR:", scores)
print("Média  usando SVR:", scores.mean())
# Out:
# Scores usando SVR: [0.03650144 0.42470959 0.56568541 0.22890503 0.544448  ]
# Média  usando SVR: 0.36004989295982326

# %% [markdown]
# ### Scores para KNN

# %%
scores = cross_val_score(knn, X,Y, cv=5, scoring = "r2")
print("Scores usando KNN:", scores)
print("Média  usando KNN:", scores.mean())
# Out:
# Scores usando KNN: [0.40424341 0.3348053  0.32126725 0.37172809 0.38687428]
# Média  usando KNN: 0.36378366701125736

# %% [markdown]
# ## Predição com dados de TESTE

# %% [markdown]
# ### Predição KNN e SVM

# %%
#SVM
newPreds= model.predict(X_test[features]).astype(int)

#add to the dataframes
X_test['fitted'] = newPreds

# KNN
newPreds2 = knn.predict(X_test[features]).astype(int)

X_test['fitted2'] = newPreds2

# %%
#predictions = knn.predict(Xt).astype(int)
#submission['Infectados'] = np.concatenate([predictions])

plt.figure(figsize=(30,10))
submission['Infectados'].plot( label="Casos Reais")
X_test['fitted'].plot(label="Predicões com KNN")
X_test['fitted2'].plot(label="Predicões com SVM")

plt.title("Dengue Casos Preditos vs. Casos Reais")
plt.legend()
plt.xlabel('N. de Semanas')
plt.ylabel('Total de Infectados')
# Out:
# Text(0, 0.5, 'Total de Infectados')

# %% [markdown]
# ## Conclusão
# ### Podemos afirmar que os modelos baseados em SVM KNN funcionam bem para previsão de casos dengue em Fortaleza, com uma precisão maior para o modelo baseado no KNN
